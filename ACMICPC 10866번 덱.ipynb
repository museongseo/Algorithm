# %%
import sys
input = lambda : sys.stdin.readline().strip()
deque = []

n = int(input())

for i in range(n):
    command = input().rstrip()
    if " " in command :
        a, b = command.split()
        if a == 'push_front' : deque.insert(0,b)
        elif a == 'push_back' : deque.append(b)
    elif "pop_front" == command : 
        if len(deque) == 0 : print(-1)
        else : print(deque.pop(0))
    elif "pop_back" == command : 
        if len(deque) == 0 : print(-1)
        else : print(deque.pop(-1))
    elif 'size' == command : print(len(deque))
    elif 'empty' == command :
        if len(deque) == 0 : print(1)
        else : print(0)
    elif 'front' == command :
        if len(deque) == 0 : print(-1)
        else : print(deque[0])
    elif 'back' == command :
        if len(deque) == 0 : print(-1)
        else : print(deque[-1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-8896ce7b4e97> in <module>()
#       2 input = lambda : sys.stdin.readline().strip()
#       3 deque = []
# ----> 4 n = int(input())
#       5 for i in range(n):
#       6     command = input().rstrip()
#
# ValueError: invalid literal for int() with base 10: ''
