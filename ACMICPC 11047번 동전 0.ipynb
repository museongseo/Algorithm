# %%
N, K = map(int, input().split())
A = []
count = 0
for i in range(N):
    A.append(int(input()))
for j in range(N-1, -1, -1):
        if (K == 0):
            break
        if (A[j] > K):
            continue
        count += (K // A[j])
        K -= A[j] * (K // A[j])
print(count)
