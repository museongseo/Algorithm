# %%
N = int(input())
count = 0
min = 1000000
for f in range(9, -1 , -1):
    for e in range(9, -1 , -1):
        for d in range(9, -1 , -1):
            for c in range(9, -1 , -1):
                for b in range(9, -1 , -1):
                    for a in range(9, -1 , -1):
                        if ((N - 2 * f - 11 * e - 101 * d - 1001 * c - 10001 * b - 100001 * a) == 0) :
                            count = 1
                            num = 100000 * a + 10000 * b + 1000 * c + 100 * d + 10 * e + f
                            if (min > num) : min = num
if (count == 0) :
    print(0)
else :
    print(min)
