# %%
N = int(input())
List = []
for _ in range(0, N):
    word = input()
    count = len(word)
    List.append((word,count))
List = list(set(List))
List.sort(key = lambda word: (word[1], word[0]))
for word in List:
    print(word[0])
# Out:
# 13
# but
# i
# wont
# hesitate
# no
# more
# no
# more
# it
# cannot
# wait
# im
# yours
# i
# im
# it
# no
# but
# more
# wait
# wont
# yours
# cannot
# hesitate
