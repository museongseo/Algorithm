# %%
N = int(input())
List = []
for _ in range(0, N):
    age,name = input().split()
    age = int(age)
    List.append((age,name))
List.sort(key = lambda people:people[0])
for people in List:
    print(people[0], people[1])
