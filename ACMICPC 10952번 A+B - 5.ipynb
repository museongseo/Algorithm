# %% [markdown]
# <a href="https://colab.research.google.com/github/museongseo/Algorithm/blob/main/ACMICPC%2010952%EB%B2%88%20A%2BB%20-%205.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
while (1):
  a, b = map(int, input().split())
  if (a == 0 and b == 0):
    break;
  else : print(a+b)
# Out:
# 1 1
# 2
# 2 3
# 5
# 3 4
# 7
# 9 8
# 17
# 5 2
# 7
# 0 0
