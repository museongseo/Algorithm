# %%
N = int(input())
if (N >= 8):
    if (N % 5 == 0):
        print(N // 5)
    elif (N % 5 == 1):
        print(N // 5 + 1)
    elif (N % 5 == 2) :
        print(N // 5 + 2)
    elif (N % 5 == 3) :
        print(N // 5 + 1)
    elif (N % 5 == 4) :
        print(N // 5 + 2)
    else : print(-1)
else :
    if ((N % 3 == 0) or (N % 5 == 0)):
        if (N == 6):
            print (N // 3)
        else :
            print(1)
    else :
        print(-1)
