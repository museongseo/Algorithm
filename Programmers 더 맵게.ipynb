# %%
def solution(scoville, K):
    count = 0
    while min(scoville) < K :
        scoville.sort()
        scoville.append(scoville.pop(0) + 2 * scoville.pop(0))
        count += 1
    return count

# %% [markdown]
# 210723) 대부분의 테스트 항목에 대해 정확성 항목에 있어서는 통과했지만, 몇 개의 항목에 대해 런타임 에러가 발생하고 효율성 테스트를 통과하지 못했다.

# %%
def solution(scoville, K):
    count = 0
    while min(scoville) < K :
        scoville.sort()
        try :
            scoville.append(scoville.pop(0) + 2 * scoville.pop(0))
        except IndexError :
            return -1
        count += 1
    return count

# %% [markdown]
# 210724) 이 코드도 마찬가지로 -1 을 리턴하는 조건을 작성하니 모든 테스트케이스에 대해서 정확성 테스트는 통과했지만, 모든 효율성 테스트를 통과하지 못했다.

# %%
import heapq

def solution(scoville, K):
    count = 0
    heap = []
    mix = 0
    for num in scoville:
        heapq.heappush(heap, num)
    while heap[0] < K :
        heapq.heappush(heap, heapq.heappop(heap) + 2 * heapq.heappop(heap))
        count += 1
    return count

# %%
import heapq

def solution(scoville, K):
    count = 0
    heap = []
    mix = 0
    for num in scoville:
        heapq.heappush(heap, num)
    while heap[0] < K :
        try :
            heapq.heappush(heap, heapq.heappop(heap) + 2 * heapq.heappop(heap))
        except IndexError :
            return -1
        count += 1
    return count

# %% [markdown]
# 210723) 더 맵게 문제가 Heap 카테고리 안에 있으므로 heapq 를 이용하여 코드를 다시 작성해보았다. 하지만 마찬가지로 몇 개의 항목에 대해 런타임 에러가 발생했다. 대신 모든 효율성 테스트에 대해 통과하는 모습을 보여주었다.

# %% [markdown]
# 210724) 모든 음식의 스코빌 지수를 K 이상으로 만들 수 없는 경우 -1 을 리턴한다는 조건을 아예 빠뜨리고 있었다.
