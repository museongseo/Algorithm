# %%
def solution(participant, completion):
    for part in participant:
        for comp in completion:
            if part == comp:
                participant.remove(part)
    print(participant)

# %%
participant = ["marina", "josipa", "nikola", "vinko", "filipa"]
completion = ["josipa", "filipa", "marina", "nikola"]
solution(participant, completion)
# Out:
# ['josipa', 'vinko']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c276a9a08bf5> in <module>
#       1 participant = ["marina", "josipa", "nikola", "vinko", "filipa"]
#       2 completion = ["josipa", "filipa", "marina", "nikola"]
# ----> 3 solution(participant, completion)
#
# <ipython-input-1-bcfe800b49a3> in solution(participant, completion)
#       5                 participant.remove(part)
#       6     print(participant)
# ----> 7     return answer
#
# NameError: name 'answer' is not defined
